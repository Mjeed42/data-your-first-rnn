# %% [markdown]
# # Your first Recurrent Neural Network (RNN)

# %% [markdown]
# 🙌 Welcome to RNNs! After using CNNs in the previous lesson to deal with images (spatial data), you are going to deal with time-related data (***temporal data***).
#
# 🎯 Goals of this warm-up challenge:
#
# 1. Understand what temporal data is
# 2. Build your first Recurrent Neural Networks

# %% [markdown]
# _PS: No need to use Google Colab ❌_

# %% [markdown]
# ## (1) 📚 The dataset

# %% [markdown]
# _Disclaimer: nothing to code by yourself in this section, read it carefully and run the cells. We want you to focus on the RNN and LSTM models, not some Pythonesque questions_ 😉

# %% [markdown]
# 🔢 Imagine that we have access to some data about employees in a company.

# %%
import numpy as np

X = np.load('X.npy')
y = np.load('y.npy')

# %%
X.shape, y.shape
# Out:
# ((25000, 10, 3), (25000,))

# %% [markdown]
# ☝️ The dataset describes the evolution of the **employment status of 25 000 employees, year after year**: each sequence corresponds to 10 consecutive years, where each year describes a job situation, comprising 3 components
# - the salary,
# - the number of people under someone's responsibility,
# - the size of the company.
#
# 🕵🏻 To understand the dataset a bit better, let's look at the data of the first employee.

# %%
import pandas as pd

employee_0 = pd.DataFrame(X[0],
                          columns=['salary',
                                   'responsibility',
                                   'company_size'])
round(employee_0,2)
# Out:
#    salary  responsibility  company_size
# 0    1.48             9.0         121.0
# 1    0.50            19.0         121.0
# 2    1.43            19.0         121.0
# 3    1.55            19.0         121.0
# 4    1.60            20.0         121.0
# 5    1.78            36.0         121.0
# 6    3.71            36.0         190.0
# 7    3.77           134.0         211.0
# 8   16.15           138.0         211.0
# 9   16.68           138.0         227.0

# %% [markdown]
# 🎯 The goal in this challenge is to predict the montly salary on the 11th year for each of these 25,000 employees, based on the past observations.

# %%
# For example, the first employee earns 6.499 k USD per month
# during the 11th year at the company
y[0]
# Out:
# 16.703

# %% [markdown]
# 📈 To help you get a better understanding about the evolution of the salaries, the number of people under their responsibility and the company size over the years, you can run the cell down below. Can you visually detect some correlations between these three variables?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

number_of_employees = len(X)

### Choosing random employees
##### As the employees are selected randomly, feel free to re-run this cell a few times !

number_of_randomly_selected_employees = 5

random_selection = np.random.randint(0,
                                     number_of_employees,
                                     number_of_randomly_selected_employees)


### Plotting data for the selected employees

plt.title('Salary')
for r in random_selection:
    plt.plot(X[r, :, 0],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

plt.title('# People responsibile for')
for r in random_selection:
    plt.plot(X[r, :, 1],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

plt.title('Company sizes')
for r in random_selection:
    plt.plot(X[r, :, 2],label=f"Employee number {r}",linestyle=":",marker="o")
    plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# 🕵🏻 **Data Exploration** 🕵🏻 Look at the distribution of:
# * all the salaries during the 10th year,
# * people under someone's responsibility,
# * and the company sizes
#
# to get a better understanding of the variability of observations

# %%
import seaborn as sns

plt.title("Salaries on the 10th year")
sns.histplot(X[:, -1, 0].flatten()) # all the employees, last year, feature #0 = salaries
plt.show()

plt.title("# of people under someone's responsibility")
sns.histplot(X[:, :, 1].flatten()) # all the employees, all the years, feature #1 = responsabilities
plt.show()

plt.title("Company size")
sns.histplot(X[:, :, 2].flatten()) # all the employees, all the years, feature #2 = company size
plt.show()

# %% [markdown]
# ✂️ **Hold-out method** Let's split the dataset in a train and test set (80/20)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# Notice that we are train_test_splitting the 25 000 employees!

# %% [markdown]
# ## (2) 💻 A Simple RNN

# %% [markdown]
# 🤗 Now that you are familiar with this company's dataset, you will create your first Recurrent Neural Network. Let's start with a simple architecture.

# %% [markdown]
# ❓ **Question** ❓ Write a model that has:
# - a ***Normalization*** layer adapted to the training set
# - a ***SimpleRNN*** layer with 20 *units* (don't forget that `tanh` is better suited as an activation function for a Recurrent Layer)
# - a ***Dense*** layer with 10 neurons
# - a ***Dense*** layer specific to your task (= to ***predict*** a salary)
#
# 👩🏻‍🏫 <u>Remember</u>: You don't need to specify an `input_shape`: as soon as your Normalizer has been adapted to your train set, it has memorized the input shape!

# %%
from tensorflow.keras.layers import Normalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Flatten

# %%
# Create the model
model = Sequential([
    Normalization(),  # Normalization layer
    SimpleRNN(20, activation='tanh'),  # SimpleRNN layer with 20 units
    Dense(10, activation='relu'),  # Dense layer with 10 neurons
    Dense(1)  # Output layer to predict the salary
])

# %%
# YOUR CODE HERE
model.layers[0].adapt(X_train)

# %% [markdown]
# ❓ **Question**: How many trainable parameters does your RNN have ❓

# %%
# Build the model by providing an input shape
model.build(input_shape=(None, X_train.shape[1], X_train.shape[2]))

# %%
# YOUR CODE HERE
# Display the model summary
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_8 (Normalizat  (None, 10, 3)            7
#  ion)
#
#  simple_rnn_3 (SimpleRNN)    (None, 20)                480
#
#  dense_16 (Dense)            (None, 10)                210
#
#  dense_17 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 708
# Trainable params: 701
# Non-trainable params: 7
# _________________________________________________________________

# %% [markdown]
# ❓ **Question** ❓ Try to recompute the number of parameters manually.

# %% [markdown]
# >
# - <u> Normalization Layer</u>:
#     - This layer has $\color{red}{n_x = 3} $ features (salary, responsibility, company size) to normalize. Each of them requires to compute the <font color=blue>_mean_</font>  and the <font color=blue>_standard_deviation_</font>. So we have $\color{red}{n_x = 3} \times \color{blue}{2} = 6$ non-trainable parameters. The 7th parameter is a bias initially set to 0.
#
# - <u> Recurrent Layer</u>:
#     - If $\color{green}{n_h = 20} $ RNN units are applied in parallel to $\color{red}{n_x = 3} $ features, then the Recurrent Layer has $\color{green}{n_h}(\color{green}{n_h} + \color{red}{n_x} + 1) = \color{green}{20} \times (\color{green}{20}+\color{red}{3}+1) = \color{green}{20} \times 24 = 480$ parameters to train.
#     - Notice how this number is *independent* of the length of each sequence (here 10 days)
#
# - <u> Dense Layer</u>:
#     - Starting with $\color{green}{n_h = 20} $ RNN units and $1$ bias, using 10 neurons, the Dense Layer has $ (\color{green}{20}+1) \times 10 = 21 \times 10 = 210$ parameters
#
# - <u> Predictive Dense Layer</u>:
#     - Starting with $10$ neurons and $1$ bias, using 1 neuron to predict the 11th salary, the Predictive Dense Layer has $ (10+1) \times 1 = 11 \times 1 = 11$ parameters

# %% [markdown]
# <details>
#     <summary><i>Answer</i></summary>
#
#
# - <u> Normalization Layer</u>:
#     - This layer has $\color{red}{n_x = 3} $ features (salary, responsibility, company size) to normalize. Each of them requires to compute the <font color=blue>_mean_</font>  and the <font color=blue>_standard_deviation_</font>. So we have $\color{red}{n_x = 3} \times \color{blue}{2} = 6$ non-trainable parameters. The 7th parameter is a bias initially set to 0.
#
# - <u> Recurrent Layer</u>:
#     - If $\color{green}{n_h = 20} $ RNN units are applied in parallel to $\color{red}{n_x = 3} $ features, then the Recurrent Layer has $\color{green}{n_h}(\color{green}{n_h} + \color{red}{n_x} + 1) = \color{green}{20} \times (\color{green}{20}+\color{red}{3}+1) = \color{green}{20} \times 24 = 480$ parameters to train.
#     - Notice how this number is *independent* of the length of each sequence (here 10 days)
#
# - <u> Dense Layer</u>:
#     - Starting with $\color{green}{n_h = 20} $ RNN units and $1$ bias, using 10 neurons, the Dense Layer has $ (\color{green}{20}+1) \times 10 = 21 \times 10 = 210$ parameters
#
# - <u> Predictive Dense Layer</u>:
#     - Starting with $10$ neurons and $1$ bias, using 1 neuron to predict the 11th salary, the Predictive Dense Layer has $ (10+1) \times 1 = 11 \times 1 = 11$ parameters
#
# </details>

# %% [markdown]
# ❓ **Question** ❓ Compile your model. For RNN, we recommend you to use the ***rmsprop*** optimizer (instead of *adam*).

# %%
# YOUR CODE HERE
model.compile(optimizer='rmsprop', loss='mae', metrics=['mae'])

# %% [markdown]
# ❓ **Questions** ❓
#
# * Train your model on your training dataset:
#     * use a Validation Split of 20%
#     * and an Early Stopping Criterion with patience $= 5 $
# * Evaluate your performance on the test set

# %%
# YOUR CODE HERE
from tensorflow.keras.callbacks import EarlyStopping

# Define Early Stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,  # Set a high number of epochs; early stopping will stop training earlier
    batch_size=32,
    callbacks=[early_stopping]
)

# Evaluate the model on the test set
test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")
# Out:
# Epoch 1/100
# 500/500 [==============================] - 2s 4ms/step - loss: 1.6215 - mae: 1.6215 - val_loss: 0.6913 - val_mae: 0.6913
# Epoch 2/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.5495 - mae: 0.5495 - val_loss: 0.3961 - val_mae: 0.3961
# Epoch 3/100
# 500/500 [==============================] - 1s 3ms/step - loss: 0.4180 - mae: 0.4180 - val_loss: 0.3331 - val_mae: 0.3331
# Epoch 4/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.3739 - mae: 0.3739 - val_loss: 0.3356 - val_mae: 0.3356
# Epoch 5/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.3514 - mae: 0.3514 - val_loss: 0.3080 - val_mae: 0.3080
# Epoch 6/100
# 500/500 [==============================] - -1s -1045us/step - loss: 0.3369 - mae: 0.3369 - val_loss: 0.3182 - val_mae: 0.3182
# Epoch 7/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.3270 - mae: 0.3270 - val_loss: 0.2785 - val_mae: 0.2785
# Epoch 8/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.3183 - mae: 0.3183 - val_loss: 0.2968 - val_mae: 0.2968
# Epoch 9/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.3136 - mae: 0.3136 - val_loss: 0.2720 - val_mae: 0.2720
# Epoch 10/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.3093 - mae: 0.3093 - val_loss: 0.2618 - val_mae: 0.2618
# Epoch 11/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.3041 - mae: 0.3041 - val_loss: 0.2636 - val_mae: 0.2636
# Epoch 12/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.3022 - mae: 0.3022 - val_loss: 0.2798 - val_mae: 0.2798
# Epoch 13/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.2987 - mae: 0.2987 - val_loss: 0.2617 - val_mae: 0.2617
# Epoch 14/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.2939 - mae: 0.2939 - val_loss: 0.2745 - val_mae: 0.2745
# Epoch 15/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.2934 - mae: 0.2934 - val_loss: 0.3136 - val_mae: 0.3136
# Epoch 16/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.2903 - mae: 0.2903 - val_loss: 0.2641 - val_mae: 0.2641
# Epoch 17/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.2884 - mae: 0.2884 - val_loss: 0.2559 - val_mae: 0.2559
# Epoch 18/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.2865 - mae: 0.2865 - val_loss: 0.2398 - val_mae: 0.2398
# Epoch 19/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.2852 - mae: 0.2852 - val_loss: 0.3032 - val_mae: 0.3032
# Epoch 20/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.2831 - mae: 0.2831 - val_loss: 0.2343 - val_mae: 0.2343
# Epoch 21/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.2815 - mae: 0.2815 - val_loss: 0.2940 - val_mae: 0.2940
# Epoch 22/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.2798 - mae: 0.2798 - val_loss: 0.2341 - val_mae: 0.2341
# Epoch 23/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.2783 - mae: 0.2783 - val_loss: 0.2545 - val_mae: 0.2545
# Epoch 24/100
# 500/500 [==============================] - 2s 3ms/step - loss: 0.2779 - mae: 0.2779 - val_loss: 0.3294 - val_mae: 0.3294
# Epoch 25/100
# 500/500 [==============================] - 0s 718us/step - loss: 0.2753 - mae: 0.2753 - val_loss: 0.2597 - val_mae: 0.2597
# Epoch 26/100
# 500/500 [==============================] - 2s 5ms/step - loss: 0.2763 - mae: 0.2763 - val_loss: 0.2658 - val_mae: 0.2658
# Epoch 27/100
# 500/500 [==============================] - 2s 4ms/step - loss: 0.2749 - mae: 0.2749 - val_loss: 0.2960 - val_mae: 0.2960
# Test Loss: 0.24962154030799866, Test MAE: 0.24962154030799866

# %%
##    from tensorflow.keras.layers import Dropout, LSTM
##
##    # Create a new model with LSTM and Dropout
##    model = Sequential([
##        Normalization(),
##        LSTM(50, activation='tanh', return_sequences=True),  # LSTM with 50 units
##        Dropout(0.2),  # Dropout to prevent overfitting
##        LSTM(20, activation='tanh'),  # Another LSTM layer
##        Dense(10, activation='relu'),
##        Dense(1)
##    ])
##
##    # Adapt the Normalization layer
##    model.layers[0].adapt(X_train)
##
##    # Compile the model with a lower learning rate
##    model.compile(optimizer='rmsprop', loss='mae', metrics=['mae'])
##
##    # Define Early Stopping
##    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
##
##    # Train the model
##    history = model.fit(
##        X_train, y_train,
##        validation_split=0.2,
##        epochs=100,
##        batch_size=64,  # Increased batch size
##        callbacks=[early_stopping]
##    )
##
##    # Evaluate the model on the test set
##    test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)
##    print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")

# %% [markdown]
# ## (3) 💻 Baseline comparison

# %% [markdown]
# > ❗️ **Important reminder** ❗️
# >
# > ***Always remember to compare your Deep Learning models, and more generally any Machine Learning model, to a baseline model.***
#
# 🧑🏻‍🏫 Remember that our goal is to predict the salary of the employees for the 11th year. It is a ***Regression task***. What baseline could we build?
# 1. In the case of a traditional regression model, a baseline prediction for `y_test` is  to **predict the average of `y_train`**... but this option could be irrelevant for time-related series. Theoretically, someone's salary is supposed to increase over the years!
# 2. An alternative baseline prediction for a regression task is to **predict the last seen value**

# %% [markdown]
# ❓ **Questions** ❓
# * Compute the Mean Absolute Error of a baseline model that predicts that the salary remains constant between the 10-th and 11-th year
# * Compare this baseline model to your RNN

# %%
# YOUR CODE HERE
# Using the last salary in X_test to predict the next salary
y_test_baseline = X_test[:, -1, 0]  # Last salary in the sequence
mae_baseline = np.mean(np.abs(y_test - y_test_baseline))  # Compute MAE

print(f"Baseline MAE: {mae_baseline}")
# Out:
# Baseline MAE: 0.5457803979015351

# %% [markdown]
# 👉 If you are stuck with this question, try `(4) LSTM` and come back to this afterwards.
#
# 🧑🏻‍🏫 Ask a TA if needed. Look at the answer only if you already tried to answer these questions unsuccessfully.
#
# <details>
#     <summary><i>Answer</i></summary>
#
#
# ```python
# # Using the last salary in X to predict the next salary
# y_test_baseline = X_test[:, -1, 0]
# mae_baseline = np.mean(np.abs(y_test - y_test_baseline))
# ```
#
# </details>

# %% [markdown]
# 😁 You should notice that your RNN performs a bit better than a baseline model.

# %% [markdown]
# ## (4) 💻 LSTM: Long-Short Term Memory

# %% [markdown]
# ❓ **Questions** ❓
#
# * Write the exact same model, but with a `LSTM` layer instead of a `SimpleRNN` layer
# * Evaluate your performance on the test set

# %%
# YOUR CODE HERE
from tensorflow.keras.layers import LSTM

# Create the model with LSTM
model = Sequential([
    Normalization(),
    LSTM(20, activation='tanh'),  # LSTM layer with 20 units
    Dense(10, activation='relu'),  # Dense layer with 10 neurons
    Dense(1)  # Output layer to predict the salary
])

# Adapt the Normalization layer
model.layers[0].adapt(X_train)

# Compile the model
model.compile(optimizer='rmsprop', loss='mae', metrics=['mae'])

# Train the model
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=[early_stopping]
)

# Evaluate the model on the test set
test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss}, Test MAE: {test_mae}")
# Out:
# Epoch 1/100
# 500/500 [==============================] - 5s 7ms/step - loss: 1.8128 - mae: 1.8128 - val_loss: 0.7552 - val_mae: 0.7552
# Epoch 2/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.5858 - mae: 0.5858 - val_loss: 0.4063 - val_mae: 0.4063
# Epoch 3/100
# 500/500 [==============================] - 3s 7ms/step - loss: 0.4045 - mae: 0.4045 - val_loss: 0.3054 - val_mae: 0.3054
# Epoch 4/100
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3491 - mae: 0.3491 - val_loss: 0.3669 - val_mae: 0.3669
# Epoch 5/100
# 500/500 [==============================] - 4s 8ms/step - loss: 0.3300 - mae: 0.3300 - val_loss: 0.3089 - val_mae: 0.3089
# Epoch 6/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.3165 - mae: 0.3165 - val_loss: 0.2575 - val_mae: 0.2575
# Epoch 7/100
# 500/500 [==============================] - 3s 5ms/step - loss: 0.3058 - mae: 0.3058 - val_loss: 0.2732 - val_mae: 0.2732
# Epoch 8/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2971 - mae: 0.2971 - val_loss: 0.2838 - val_mae: 0.2838
# Epoch 9/100
# 500/500 [==============================] - 3s 5ms/step - loss: 0.2914 - mae: 0.2914 - val_loss: 0.2861 - val_mae: 0.2861
# Epoch 10/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2856 - mae: 0.2856 - val_loss: 0.2544 - val_mae: 0.2544
# Epoch 11/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2798 - mae: 0.2798 - val_loss: 0.2659 - val_mae: 0.2659
# Epoch 12/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2757 - mae: 0.2757 - val_loss: 0.2403 - val_mae: 0.2403
# Epoch 13/100
# 500/500 [==============================] - 5s 9ms/step - loss: 0.2712 - mae: 0.2712 - val_loss: 0.2323 - val_mae: 0.2323
# Epoch 14/100
# 500/500 [==============================] - 5s 9ms/step - loss: 0.2683 - mae: 0.2683 - val_loss: 0.2294 - val_mae: 0.2294
# Epoch 15/100
# 500/500 [==============================] - 3s 7ms/step - loss: 0.2663 - mae: 0.2663 - val_loss: 0.2763 - val_mae: 0.2763
# Epoch 16/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2638 - mae: 0.2638 - val_loss: 0.2421 - val_mae: 0.2421
# Epoch 17/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2616 - mae: 0.2616 - val_loss: 0.2391 - val_mae: 0.2391
# Epoch 18/100
# 500/500 [==============================] - 1s 2ms/step - loss: 0.2602 - mae: 0.2602 - val_loss: 0.2327 - val_mae: 0.2327
# Epoch 19/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2578 - mae: 0.2578 - val_loss: 0.2268 - val_mae: 0.2268
# Epoch 20/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2576 - mae: 0.2576 - val_loss: 0.2402 - val_mae: 0.2402
# Epoch 21/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2548 - mae: 0.2548 - val_loss: 0.2298 - val_mae: 0.2298
# Epoch 22/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2552 - mae: 0.2552 - val_loss: 0.2260 - val_mae: 0.2260
# Epoch 23/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2544 - mae: 0.2544 - val_loss: 0.2726 - val_mae: 0.2726
# Epoch 24/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2523 - mae: 0.2523 - val_loss: 0.2524 - val_mae: 0.2524
# Epoch 25/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2519 - mae: 0.2519 - val_loss: 0.2224 - val_mae: 0.2224
# Epoch 26/100
# 500/500 [==============================] - 3s 7ms/step - loss: 0.2510 - mae: 0.2510 - val_loss: 0.2398 - val_mae: 0.2398
# Epoch 27/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2507 - mae: 0.2507 - val_loss: 0.2239 - val_mae: 0.2239
# Epoch 28/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2491 - mae: 0.2491 - val_loss: 0.2164 - val_mae: 0.2164
# Epoch 29/100
# 500/500 [==============================] - 1s 1ms/step - loss: 0.2488 - mae: 0.2488 - val_loss: 0.2254 - val_mae: 0.2254
# Epoch 30/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2477 - mae: 0.2477 - val_loss: 0.2649 - val_mae: 0.2649
# Epoch 31/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2469 - mae: 0.2469 - val_loss: 0.2252 - val_mae: 0.2252
# Epoch 32/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2468 - mae: 0.2468 - val_loss: 0.2391 - val_mae: 0.2391
# Epoch 33/100
# 500/500 [==============================] - 3s 6ms/step - loss: 0.2462 - mae: 0.2462 - val_loss: 0.2173 - val_mae: 0.2173
# Test Loss: 0.22438764572143555, Test MAE: 0.22438764572143555

# %% [markdown]
# 💪 The LSTM should perform a bit better than the SimpleRNN with a lower MAE.

# %% [markdown]
# 🏁 Congratulations! You know how to train a RNN on sequential data.
#
#
# 💾 Do not forget to git add/commit/push your notebook...
#
# 🚀 ... and move to the next challenge!
#
# ---
#
# <u>Note</u>: The sequences you worked with are totally fake. In case, you need to train and reproduce similar data, you can find below the functions that have been used to simulate such a dataset.

# %% [markdown]
# ## 🛠 (Utils)

# %%
def create_sequences(number):
    X, y = [], []

    for i in range(number):
        x_i, y_i = create_individual_sequence(10)
        X.append(x_i)
        y.append(y_i)

    return np.array(X), np.array(y)

def create_individual_sequence(length):
    company_sizes = []
    nb_persons = []
    salaries = []


    # Education level
    educ_level = [max(0, int(np.random.normal(10, 2)))]*length

    # Company size
    current_size = int(1 + np.random.beta(.4, 4)*500)
    for i in range(length):
        if not np.random.randint(4): # Change 1 out of 3 possibilities
            current_size = int(max(1, np.random.normal(current_size, 50)))
        company_sizes.append(current_size)

    # Number of persons
    nb_iter = np.random.beta(.15, 4)*300
    for i in range(length):
        if not np.random.randint(2): # Change 1 out of 2 possibilities
            R_1 = np.random.beta(0.5, 8)*3
            nb_iter = nb_iter + max(-2, R_1*company_sizes[i] + np.random.randint(-2, 2))
            nb_iter = max(0, nb_iter)
            nb_iter = int(min(company_sizes[i]-1, nb_iter))
        nb_persons.append(nb_iter)


    # Salary
    salary_iter = max(800, int(np.random.normal(1200, 300)+ 0.05*company_sizes[0] +  np.random.normal(40, 400)))
    salaries.append(salary_iter)
    for i in range(1, length + 1):
        R_1 = np.random.normal(100, 50)
        change_person = nb_persons[i-1] - nb_persons[i-2]
        change_company = max(0, company_sizes[i-1] - company_sizes[i-2])
        salary_iter = salary_iter + 0.05*change_company + change_person*R_1 + np.random.normal(100, 50)
        salary_iter = max(int(salary_iter), 500)

        salaries.append(salary_iter)

    y = salaries[-1]/1000
    salaries = [_/1000 for _ in salaries[:-1]]

    return np.array([salaries, nb_persons, company_sizes]).T, y

# %%
X, y = create_sequences(25000)

np.save('X', X.astype(np.float32))
np.save('y', y)
